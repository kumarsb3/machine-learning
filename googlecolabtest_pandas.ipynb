# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Pandas - used for data retrieval, processing, transformation, sorting, etc..

# %%
#series - 1 dimensional list with indices and values, analogous to dictionary
s = pd.Series([1, 3, 5, np.nan, 6, 8]) #np.nan is for empty value
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#create series using a dictionary
d = {'a': 1, 'b': 2, 'c': 3}
s = pd.Series(d)
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(d, index=['b', 'c', 'd', 'a'])
# Out:
# b    2.0
# c    3.0
# d    NaN
# a    1.0
# dtype: float64

# %%
d = {'a':'a','b':3.2} #string is object in python, overwrites type with 1st type
pd.Series(d)
# Out:
# a      a
# b    3.2
# dtype: object

# %%
#slicing
np.random.seed(100)
data = np.random.randn(5)
index=['a', 'b','c','d','e']
#s=pd.Series(data,index)
s=pd.Series(data = data, index=index)
s
#print(s.index, s.values)
# Out:
# a   -1.749765
# b    0.342680
# c    1.153036
# d   -0.252436
# e    0.981321
# dtype: float64

# %%
np.random.seed(10)
b=np.random.randn(6)
c=['r','s','t','u','v','w']
d=pd.Series(data=b, index=c)
d
d[:-5]
# Out:
# r    1.331587
# dtype: float64

# %%
s[:3] # same as s[0,3] i.e. [0,1,2]
s[3]
# Out:
# /tmp/ipython-input-3356576477.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[3]
# np.float64(-0.25243603652138985)

# %%
s[:-2] #reverse indexing starts from negative end to start i.e. [0,1,2] = [-3,-2,-1]
# Out:
# a   -1.749765
# b    0.342680
# c    1.153036
# dtype: float64

# %%
s[3:]
# Out:
# d   -0.252436
# e    0.981321
# dtype: float64

# %%
s[[1,4,2]] # slicing for picking specific value based on index
# Out:
# /tmp/ipython-input-178037083.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[[1,4,2]]
# b    0.342680
# e    0.981321
# c    1.153036
# dtype: float64

# %%
s
np.exp(s)  #exponential of column s
# Out:
# a    0.173815
# b    1.408718
# c    3.167795
# d    0.776906
# e    2.667978
# dtype: float64

# %%
s['e']
# Out:
# np.float64(0.9813207869512316)

# %%
#'e' in s
3 in s
# Out:
# False

# %% [markdown]
# # Data frame
#
# data frame is 2D structure, representation of a table. Its a collection of series where series is 1D structure
#
# Data frame can n=be instantiated from a dictionary of series as columns OR using an array of lists as rows

# %%
#from dictionary
data = {'one' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
     'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(data)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
# create test data frame
dat = {'age': pd.Series([23,34,45,50,10], index = ['1','2','3','4','5']),'weight':pd.Series([10,20,30,40,50,60,70], index = ['1','2','4','5','3','6','7'])}
f=pd.DataFrame(dat)
f
# Out:
#     age  weight
# 1  23.0      10
# 2  34.0      20
# 3  45.0      50
# 4  50.0      30
# 5  10.0      40
# 6   NaN      60
# 7   NaN      70

# %%
pd.DataFrame(dat,index=['3','4','7'])
# Out:
#     age  weight
# 3  45.0      50
# 4  50.0      30
# 7   NaN      70

# %%
#Data frame from Lists

a = ['apple', 30, 1000]
b = ['river', 40, 5000, 10000]
c = ['canyon', 50]
df = pd.DataFrame([a,b,c])
df
# Out:
#         0   1       2        3
# 0   apple  30  1000.0      NaN
# 1   river  40  5000.0  10000.0
# 2  canyon  50     NaN      NaN

# %%
df=pd.DataFrame([a,b,c],columns=['name', 'age','salary','worth'])
df
# Out:
#      name  age  salary    worth
# 0   apple   30  1000.0      NaN
# 1   river   40  5000.0  10000.0
# 2  canyon   50     NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   salary  2 non-null      float64
#  3   worth   1 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df.head()
# Out:
#      name  age  salary    worth
# 0   apple   30  1000.0      NaN
# 1   river   40  5000.0  10000.0
# 2  canyon   50     NaN      NaN

# %%
d=['chinna',25,12000,150000]

df=pd.DataFrame([a,b,c,d],columns=['name', 'age','salary','worth'])
df
# Out:
#      name  age   salary     worth
# 0   apple   30   1000.0       NaN
# 1   river   40   5000.0   10000.0
# 2  canyon   50      NaN       NaN
# 3  chinna   25  12000.0  150000.0

# %%
names = ['abc','def','ghi','jkl','mno']
ages = [20,40,60,80,100]
salaries = [10000,20000,30000,40000,50000]
df=pd.DataFrame({'name':names, 'age':ages, 'salary':salaries})
df
# Out:
#   name  age  salary
# 0  abc   20   10000
# 1  def   40   20000
# 2  ghi   60   30000
# 3  jkl   80   40000
# 4  mno  100   50000

# %%
df['worth'] = df['salary']/df['age']
df['total worth'] = df['worth'] * df['age']+ df['salary']
df
# Out:
#   name  age  salary  worth  total worth
# 0  abc   20   10000  500.0      20000.0
# 1  def   40   20000  500.0      40000.0
# 2  ghi   60   30000  500.0      60000.0
# 3  jkl   80   40000  500.0      80000.0
# 4  mno  100   50000  500.0     100000.0

# %%
#copying dataframe data into new DF before deleting existing data within it
new_df= df
new_df
# Out:
#   name  age  salary  total worth
# 0  abc   20   10000      20000.0
# 1  def   40   20000      40000.0
# 2  ghi   60   30000      60000.0
# 3  jkl   80   40000      80000.0
# 4  mno  100   50000     100000.0

# %%
df.pop('worth')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'worth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3934793431.py in <cell line: 0>()
# ----> 1 df.pop('worth')
#       2 df
#
# ...

# %%
df
# Out:
#   name  age  salary  total worth
# 0  abc   20   10000      20000.0
# 1  def   40   20000      40000.0
# 2  ghi   60   30000      60000.0
# 3  jkl   80   40000      80000.0
# 4  mno  100   50000     100000.0

# %% [markdown]
# #IRIS Dataset tutorial

# %%
import pandas as pd
iris = pd.read_csv('Iris.csv')

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 7)

# %%
iris.size
# Out:
# 1050

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.T
# Out:
#                        0            1            2            3    \
# Id                       1            2            3            4
# SepalLengthCm          5.1          4.9          4.7          4.6
# SepalWidthCm           3.5          3.0          3.2          3.1
# PetalLengthCm          1.4          1.4          1.3          1.5
# PetalWidthCm           0.2          0.2          0.2          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7    \
# Id                       5            6            7            8
# SepalLengthCm          5.0          5.4          4.6          5.0
# SepalWidthCm           3.6          3.9          3.4          3.4
# PetalLengthCm          1.4          1.7          1.4          1.5
# PetalWidthCm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
# ...

# %%
iris.describe() # gives statistical values of data set
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#         'Species'],
#        dtype='object')]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.sort_values(by='SepalLengthCm', ascending=False).head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
#
#             Species
# 131  Iris-virginica
# 122  Iris-virginica
# 118  Iris-virginica
# 117  Iris-virginica
# 135  Iris-virginica

# %%
iris.sort_values(by='PetalWidthCm', ascending=False).head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 109  110            7.2           3.6            6.1           2.5
# 100  101            6.3           3.3            6.0           2.5
# 114  115            5.8           2.8            5.1           2.4
# 136  137            6.3           3.4            5.6           2.4
#
#             Species
# 144  Iris-virginica
# 109  Iris-virginica
# 100  Iris-virginica
# 114  Iris-virginica
# 136  Iris-virginica

# %%
iris['SepalLengthCm'].head() #same as below command but column names with space in between can use this format i.e. ' ' if not can use dot format as below command
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: SepalLengthCm, dtype: float64

# %%
iris.SepalLengthCm.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: SepalLengthCm, dtype: float64

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.SepalLengthCm.mean()
# Out:
# np.float64(5.843333333333334)

# %%
iris.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#Selection with .loc and .iloc
iris[['Species']].head() # [[column name]] shows in dataframe type (2D)
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris['Species'].head() # [[column name]] shows in series type (1D)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
type(iris['Species'])
# Out:
# pandas.core.series.Series

# %%
type(iris[['Species']])
# Out:
# pandas.core.frame.DataFrame

# %%
iris[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
# loc returns external index i.e. 0:3 returns 0,1,2,3

iris.loc[0:3,['SepalLengthCm', 'SepalWidthCm']]
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1

# %%
# iloc returns without external indexes i.e 0:3 returns 0,1,2
iris.iloc[0:3,[1,4]]
# Out:
#    SepalLengthCm  PetalWidthCm
# 0            5.1           0.2
# 1            4.9           0.2
# 2            4.7           0.2

# %%
iris.iloc[[0,1,2,3],[1,4,5]]
# Out:
#    SepalLengthCm  PetalWidthCm      Species
# 0            5.1           0.2  Iris-setosa
# 1            4.9           0.2  Iris-setosa
# 2            4.7           0.2  Iris-setosa
# 3            4.6           0.2  Iris-setosa

# %%
#loc is sub selection
#iat is for indexing

iris.iat[2,1] # will return specific value by indexes
# Out:
# np.float64(4.7)

# %%
iris.at[2,'SepalLengthCm'] # in at command, we can mention column name instead of index
# Out:
# np.float64(4.7)

# %% [markdown]
# #### Boolean indexing
# loc can be used to filter the rows based on conditions that return boolean values. <br>
# Note that iloc always accepts integers in the first (row level) filter.

# %%
iris.loc[iris.SepalLengthCm>7.0, ['Species', 'SepalLengthCm',
                                 'PetalLengthCm']].sort_values(by='SepalLengthCm', ascending=False).head(10)
# booleans indexing based on condition i.e. >7.0, then choosing columns and then sorting by length
# Out:
#             Species  SepalLengthCm  PetalLengthCm
# 131  Iris-virginica            7.9            6.4
# 118  Iris-virginica            7.7            6.9
# 117  Iris-virginica            7.7            6.7
# 122  Iris-virginica            7.7            6.7
# 135  Iris-virginica            7.7            6.1
# 105  Iris-virginica            7.6            6.6
# 130  Iris-virginica            7.4            6.1
# 107  Iris-virginica            7.3            6.3
# 125  Iris-virginica            7.2            6.0
# 109  Iris-virginica            7.2            6.1

# %%
iris[iris.Species.isin(['Iris-versicolor', 'Iris-virginica'])].tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris[iris.Species.isin(['Iris-versicolor', 'Iris-virginica'])]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
iris[iris.Species.str.startswith('Iris-s')].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Assignment - creating column and assign values
iris['size'] = ''

# %%
iris.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2560884115.py in <cell line: 0>()
# ----> 1 iris.head()
#
# NameError: name 'iris' is not defined

# %%
iris.loc[(iris.SepalLengthCm>7.0) & (iris.PetalLengthCm>6),'size'] = 'long'

# %%
iris.loc[iris['size']=='long',:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3993053571.py in <cell line: 0>()
# ----> 1 iris.loc[iris['size']=='long',:]
#
# NameError: name 'iris' is not defined

# %%
iris.loc[(iris.SepalLengthCm>7.0) & (iris.PetalLengthCm>6),:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 109  110            7.2           3.6            6.1           2.5
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#             Species  size
# 105  Iris-virginica  long
# 107  Iris-virginica  long
# 109  Iris-virginica  long
# 117  Iris-virginica  long
# 118  Iris-virginica  long
# 122  Iris-virginica  long
# 130  Iris-virginica  long
# 131  Iris-virginica  long
# 135  Iris-virginica  long

# %%
data = pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['size'] = ' '
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1610369302.py in <cell line: 0>()
# ----> 1 data['size'] = ' '
#       2 data.head()
#
# NameError: name 'data' is not defined

# %%
new_data = data.drop('size',axis=1)
new_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
new_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#   size
# 0
# 1
# 2
# 3
# 4

# %%
# Record Appending
import pandas as pd
alex = ['alex', 28, 500]
gaby = ['gaby', 30, 1500]
df = pd.DataFrame([alex,gaby], columns=['name', 'age','salary'])

# %%
df.loc[df.index.max()+1,:]= ['john', 20, 1000]
df.head()
# Out:
#    name   age  salary
# 0  alex  28.0   500.0
# 1  gaby  30.0  1500.0
# 2  john  20.0  1000.0

# %%
import numpy as np
import pandas as pd
iris = pd.read_csv('Iris.csv')

# %%
iris['big'] = iris.PetalLengthCm+iris.PetalWidthCm

# %%
iris.loc[iris.big==iris.big.max()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 118  119            7.7           2.6            6.9           2.3
#
#             Species  big
# 118  Iris-virginica  9.2

# %%
iris.describe() #describe command works only for numericals and not catogorical variables
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#               big
# count  150.000000
# mean     4.957333
# std      2.507662
# min      1.200000
# 25%      1.800000
# 50%      5.650000
# 75%      7.000000
# max      9.200000

# %%
iris.sum()
# Out:
# Id                                                           11325
# SepalLengthCm                                                876.5
# SepalWidthCm                                                 458.1
# PetalLengthCm                                                563.8
# PetalWidthCm                                                 179.8
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# big                                                          743.6
# dtype: object

# %%
iris.SepalLengthCm.sum()
# Out:
# np.float64(876.5)

# %%
iris.SepalLengthCm.median()
# Out:
# 5.8

# %%
iris.PetalLengthCm.std()
# Out:
# 1.7644204199522617

# %%
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  big
# 0       Iris-setosa  1.6
# 1       Iris-setosa  1.6
# 2       Iris-setosa  1.5
# 3       Iris-setosa  1.7
# 4       Iris-setosa  1.6
# ...

# %%
#Map - iterates through a series

n = [1,2,3,4]

# %%
print(list(map(lambda x: x**2, n))) # lambda is inline function in pyhton
# Out:
# [1, 4, 9, 16]

# %%
iris.SepalLengthCm.map(lambda x: x**2).head()
# Out:
# 0    26.01
# 1    24.01
# 2    22.09
# 3    21.16
# 4    25.00
# Name: SepalLengthCm, dtype: float64

# %%
# Grouping

iris.groupby('Species').SepalLengthCm.max()
# Out:
# Species
# Iris-setosa        5.8
# Iris-versicolor    7.0
# Iris-virginica     7.9
# Name: SepalLengthCm, dtype: float64

# %%
species_group = iris.groupby('Species')

# %%
species_group.get_group("Iris-versicolor").head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species  big
# 50  Iris-versicolor  6.1
# 51  Iris-versicolor  6.0
# 52  Iris-versicolor  6.4
# 53  Iris-versicolor  5.3
# 54  Iris-versicolor  6.1

# %%
iris.groupby('Species').SepalLengthCm.agg(['min','max','count','mean'])
# Out:
#                  min  max  count   mean
# Species
# Iris-setosa      4.3  5.8     50  5.006
# Iris-versicolor  4.9  7.0     50  5.936
# Iris-virginica   4.9  7.9     50  6.588

# %%
iris.groupby('Species').agg(['min','max','count','mean'])
# Out:
#                   Id                   SepalLengthCm                    \
#                  min  max count   mean           min  max count   mean
# Species
# Iris-setosa        1   50    50   25.5           4.3  5.8    50  5.006
# Iris-versicolor   51  100    50   75.5           4.9  7.0    50  5.936
# Iris-virginica   101  150    50  125.5           4.9  7.9    50  6.588
#
#                 SepalWidthCm       ... PetalLengthCm        PetalWidthCm       \
#                          min  max  ...         count   mean          min  max
# Species                            ...
# Iris-setosa              2.3  4.4  ...            50  1.464          0.1  0.6
# Iris-versicolor          2.0  3.4  ...            50  4.260          1.0  1.8
# Iris-virginica           2.2  3.8  ...            50  5.552          1.4  2.5
#
#                               big
#                 count   mean  min  max count   mean
# Species
# Iris-setosa        50  0.244  1.2  2.3    50  1.708
# ...

# %%
#JOINS

import pandas as pd
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})
middle = pd.DataFrame({
    'id':[6,7,8,9,10],
    'Name': ['abc','def','ghi','jkl','mno'],
    'subject_id':['sub6','sub7','sub8','sub9','sub10']})

print(left)
print("**************")
print(right)
print(middle)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
# **************
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5
#    id Name subject_id
# 0   6  abc       sub6
# 1   7  def       sub7
# 2   8  ghi       sub8
# 3   9  jkl       sub9
# 4  10  mno      sub10

# %%
# prompt: we would like to concatenate the left and the right dataframe above. pls suggest a pandas code

import pandas as pd

# Assuming 'left' and 'right' are your DataFrames
# You can replace these with your actual DataFrames
# join on id column and inner join
#by default it will do inner join

merged_df = pd.merge(left, right, on='id', how='inner')
merged_df
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %%
pd.merge(left,right,on='id')
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %%
# join on 2 columns
pd.merge(left,right,on=['id','subject_id'])
# Out:
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %%
pd.merge(left, right, on='subject_id', how='outer', suffixes=('_l', '_r'))
# Out:
#    id_l  Name_l subject_id  id_r Name_r
# 0   1.0    Alex       sub1   NaN    NaN
# 1   2.0     Amy       sub2   1.0  Billy
# 2   NaN     NaN       sub3   3.0   Bran
# 3   3.0   Allen       sub4   2.0  Brian
# 4   5.0  Ayoung       sub5   5.0  Betty
# 5   4.0   Alice       sub6   4.0  Bryce

# %%
pd.merge(left, right, on='subject_id', how='right', suffixes=('_l', '_r'))
# Out:
#    id_l  Name_l subject_id  id_r Name_r
# 0   2.0     Amy       sub2     1  Billy
# 1   3.0   Allen       sub4     2  Brian
# 2   NaN     NaN       sub3     3   Bran
# 3   4.0   Alice       sub6     4  Bryce
# 4   5.0  Ayoung       sub5     5  Betty

# %%
pd.merge(left, right, on='subject_id', how='inner', suffixes=('_l', '_r'))
# Out:
#    id_l  Name_l subject_id  id_r Name_r
# 0     2     Amy       sub2     1  Billy
# 1     3   Allen       sub4     2  Brian
# 2     4   Alice       sub6     4  Bryce
# 3     5  Ayoung       sub5     5  Betty

# %%
pd.merge(left, right, on='subject_id', how='outer', suffixes=('_l', '_r'))
# Out:
#    id_l  Name_l subject_id  id_r Name_r
# 0   1.0    Alex       sub1   NaN    NaN
# 1   2.0     Amy       sub2   1.0  Billy
# 2   NaN     NaN       sub3   3.0   Bran
# 3   3.0   Allen       sub4   2.0  Brian
# 4   5.0  Ayoung       sub5   5.0  Betty
# 5   4.0   Alice       sub6   4.0  Bryce

# %%
pd.concat([left,right],ignore_index=True).sort_values(by='id').reset_index(drop=True)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   1   Billy       sub2
# 2   2   Brian       sub4
# 3   2     Amy       sub2
# 4   3    Bran       sub3
# 5   3   Allen       sub4
# 6   4   Alice       sub6
# 7   4   Bryce       sub6
# 8   5  Ayoung       sub5
# 9   5   Betty       sub5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install xlrd==2.0.1 # excel specific library to read excel and excel operations
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.2
#     Uninstalling xlrd-2.0.2:
#       Successfully uninstalled xlrd-2.0.2
# ...

# %%
titanic_df = pd.read_excel('titanic3.xls','titanic3', index_col=None, na_values=['NA'])

# %%
titanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic_df.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
titanic_df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic_df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df.drop(['ticket','cabin','boat','body','home.dest'], axis=1).head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch      fare embarked
# 0  29.0000      0      0  211.3375        S
# 1   0.9167      1      2  151.5500        S
# 2   2.0000      1      2  151.5500        S
# 3  30.0000      1      2  151.5500        S
# 4  25.0000      1      2  151.5500        S

# %%
pd.value_counts(titanic_df['survived']).plot.bar()
# Out:
# /tmp/ipython-input-1184536235.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(titanic_df['survived']).plot.bar()
# <Axes: xlabel='survived'>

# %%
titanic_df['survived'].mean()
# Out:
# np.float64(0.3819709702062643)

# %%
titanic_df.groupby(['sex']).survived.mean()
# Out:
# sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
titanic_df.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.965278
#         2         0.886792
#         3         0.490741
# male    1         0.340782
#         2         0.146199
#         3         0.152130
# Name: survived, dtype: float64

# %%
titanic_df[titanic_df.age < 18].groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.875000
#         2         1.000000
#         3         0.543478
# male    1         0.857143
#         2         0.733333
#         3         0.233333
# Name: survived, dtype: float64

# %%
# !ls
# Out:
# Iris.csv  sample_data  titanic3.xls

# %%
titanic_df[titanic_df.age > 18].groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.966667
#         2         0.878049
#         3         0.436170
# male    1         0.328671
#         2         0.087591
#         3         0.158845
# Name: survived, dtype: float64

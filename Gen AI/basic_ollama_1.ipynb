# %% [markdown]
# ### Ollama basics - working with gemma3:1b model including basic prompting and Gradio Interface

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:1b    8648f39daa8f    815 MB    2 days ago

# %%
# !ollama list
# !ollama pull gemma3:1b
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:1b    8648f39daa8f    815 MB    2 days ago
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠇ pulling manifest
# pulling 7cd4618c1faf: 100% ▕██████████████████▏ 815 MB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# pulling 120007c81bf8: 100% ▕██████████████████▏  492 B
# verifying sha256 digest
# writing manifest
# success

# %%
from IPython.display import Markdown, display
import ollama
import gradio as gr

# %%
#MODEL = "llama3.2"
#MODEL = "deepseek-r1:1.5b"
MODEL = "gemma3:1b"
#MODEL = "llama3.2:1b"

# %%
system_prompt = "You are an helpful AI assistant"

#user_prompt = "Show me the recipie for Biriyani"
user_prompt = "I wish to travel to USA, Create a nice travel plan for a duration of 2 weeks. Make sure i visit all popular places of US"

# %%
response = ollama.chat(
    model = MODEL,
    messages =[
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]
)
#print(response)
display(Markdown(response['message']['content']))
# Out:
# Okay, fantastic! A two-week trip to the USA is a wonderful opportunity to experience a diverse range of landscapes, cities, and culture. Here’s a plan focusing on popular destinations, balancing iconic sights with a bit of local flavor. This itinerary prioritizes a relatively fast-paced experience, but you can adjust it based on your interests (e.g., more hiking, more museums, etc.).
#
# **Theme:** A Blend of Iconic American Experiences - History, City Life, and Natural Beauty
#
# **Duration:** 14 Days / 13 Nights
#
# **Transportation:** Primarily rental car (essential for flexibility). Consider budget airlines for longer distances.
#
# **Budget:** This will vary *significantly* based on accommodation choices, dining preferences, and activities. I'll estimate a mid-range budget – expect $2,500 - $5,000 per person (excluding flights).
#
# **Here’s the detailed plan:**
#
# **Phase 1: New York City (Days 1-4)**
#
# * **Day 1-4:** Arrive in New York City (JFK or EWR).  Check into your accommodation (Midtown, Lower East Side, or Brooklyn are good choices).
# * **Highlights:** Times Square, Statue of Liberty & Ellis Island, Financial District, 9/11 Memorial & Museum, Central Park, Museum of Modern Art (MoMA).  Evening – Broadway show!
# * **Food:**  Pizza, bagels, street food.
# * **Estimated Cost:** $800 - $1,500 (depending on lodging & activities)
#
#
# **Phase 2:  Chicago, Illinois (Days 5-7)**
#
# * **Day 5-7:** Drive from NYC to Chicago (approx. 7-8 hours).
# * **Highlights:** Millennium Park (Cloud Gate sculpture), Art Institute of Chicago, Navy Pier, Magnificent Mile shopping, deep-dish pizza.
# * **Food:** Chicago-style hot dogs, Italian beef sandwiches, and deep-dish pizza.
# * **Estimated Cost:** $700 - $1,200 (including gas & lodging)
#
#
#
# **Phase 3:  Grand Canyon National Park & Arizona (Days 8-11)**
#
# * **Day 8:** Drive from Chicago to Grand Canyon National Park (South Rim - approx. 12-14 hours).  Focus on the sunset views!
# * **Highlights:**  Grand Canyon views, viewpoints (Mather Point, Yavapai Point), Bright Angel Trail (short hike – be careful!).
# * **Food:** Pack snacks and meals for the drive.
# * **Estimated Cost:** $900 - $1,800 (including lodging, park fees, and food)
#
#
# **Phase 4:  Los Angeles, California (Days 12-14)**
#
# * **Day 12:** Drive from Grand Canyon to Los Angeles (approx. 6-7 hours).
# * **Highlights:** Hollywood Walk of Fame, TCL Chinese Theatre, Griffith Observatory, Santa Monica Pier, Getty Center (art museum).
# * **Food:**  Mexican food, seafood.
# * **Estimated Cost:** $800 - $1,500 (including lodging & activities)
#
#
# **Potential Activities & Options (Throughout the Trip):**
#
# * **Washington D.C.:** (If you have more time - could swap this day).  Visit the White House, National Mall, Smithsonian Museums.
# * **San Francisco:** (If you want a coastal experience). Golden Gate Bridge, Alcatraz, Fisherman's Wharf.
# * **New Orleans:** (For a unique cultural experience - requires more time).  French Quarter, Jazz music.
# * **Route 66:** (For a nostalgic drive - consider driving a portion of it).
#
# **Accommodation Suggestions (Mix & Match):**
#
# * **NYC:** Boutique hotels in Midtown, East Village.
# * **Chicago:** Hotels in River North or Magnificent Mile.
# * **Grand Canyon:** Stay inside the park (book WAY in advance!) or in the nearby town of Tusayan.
# * **Los Angeles:** Hotels in Hollywood, Santa Monica, or West Hollywood.
#
# **Important Notes & Customization:**
#
# * **Booking:** Book flights, accommodation, and popular attractions (like the Grand Canyon) well in advance, especially during peak season.
# * **Rental Car:**  A reliable rental car is crucial.  Consider an SUV for comfort and better road conditions.
# * **National Park Pass:**  If you plan to visit multiple National Parks, the America the Beautiful Pass is a good investment.
# * **Flexibility:** Leave some flexibility in your itinerary for spontaneous adventures.
# * **Safety:** Be aware of your surroundings, especially in crowded areas.
#
# **To help me tailor this plan even further to *your* interests, could you tell me:**
#
# 1.  **What are your primary interests?** (e.g., history, art, food, hiking, beaches, nightlife, music, etc.)
# 2.  **What's your approximate budget range per person?** (Roughly - e.g., $2,000 - $3,500)
# 3.  **What time of year are you planning to travel?** (This affects weather and crowds.)
# 4.  **Are there any specific places you already have in mind?** (e.g., a particular city, landmark, or activity?)

# %%
def shout(text):
    print(f"Shout has been called with input {text}")
    return text.upper()

# %%
shout("hello AI")
# Out:
# Shout has been called with input hello AI
# 'HELLO AI'

# %%
gr.Interface(fn=shout, inputs="textbox", outputs="textbox").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input testai

# %%
view = gr.Interface(
    fn=shout,
    inputs=[gr.Textbox(label="Your message:", lines=6)],
    outputs=[gr.Textbox(label="Response:", lines=8)],
    flagging_mode="never"
)
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input this is multi line test
# this is multi line test

# %%
def message_gpt(prompt):
    response = ollama.chat(
    model = MODEL,
    messages =[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]
    )
    return response['message']['content']

# %%
view = gr.Interface(
    fn=message_gpt,
    inputs=[gr.Textbox(label="Your message:", lines=6)],
    outputs=[gr.Textbox(label="Response:", lines=8)],
    flagging_mode="never"
)
view.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://5fd8d711df4af4e948.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5fd8d711df4af4e948.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
system_prompt = "You are a helpful assistant that responds in markdown"

def stream_gpt(prompt):
    response = ollama.chat(
    model = MODEL,
    stream= True,
    messages =[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]
    )
    result = ""
    for chunk in response:
        result += chunk.message.content or ""
        yield result

# %%
view = gr.Interface(
    fn=stream_gpt,
    inputs=[gr.Textbox(label="Your message:")],
    outputs=[gr.Markdown(label="Response:")],
    flagging_mode="never"
)
view.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * Running on public URL: https://fafb07b3a15843a148.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fafb07b3a15843a148.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def stream_model(prompt, model):
    if model=="Llama":
        MODEL = "llama3.2:1b"
    elif model=="Gemma":
        MODEL = "gemma3:1b"
    else:
        raise ValueError("Unknown model")
    
    response = ollama.chat(
    model = MODEL,
    stream= True,
    messages =[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]
    )
    result = ""
    for chunk in response:
        result += chunk.message.content or ""
        yield result

# %%
view = gr.Interface(
    fn=stream_model,
    inputs=[gr.Textbox(label="Your message:"), gr.Dropdown(["Llama", "Gemma"], label="Select model", value="Gemma")],
    outputs=[gr.Markdown(label="Response:")],
    flagging_mode="never"
)
view.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * Running on public URL: https://34a58b928776e3e26b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://34a58b928776e3e26b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def generate_prompt(product_description):
    return f"""
You are a pricing expert. Based on the product description below, predict a fair market price in USD.
Consider factors like brand, specifications, features, and comparable products. Provide exact estimate of the price instead of a price range if possible.

Product Description:
\"\"\"
{product_description}
\"\"\"

Output:
Price estimate (in USD) with brief justification.
"""

# %%
def predict_price(product_description,model):
    prompt = generate_prompt(product_description)

    if model=="Llama":
        MODEL = "llama3.2:1b"
    elif model=="Gemma":
        MODEL = "gemma3:1b"
    else:
        raise ValueError("Unknown model")
    
    system_prompt = "You are a helpful retail assistant which will predict the exact price of the product in USD"

    response = ollama.chat(
    model = MODEL,
    stream= True,
    messages =[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]
    )
    result = ""
    for chunk in response:
        result += chunk.message.content or ""
        yield result

# %%
view = gr.Interface(
    fn=predict_price,
    inputs=[gr.Textbox(label="Product Description:"), gr.Dropdown(["Llama", "Gemma"], label="Select model", value="Gemma")],
    outputs=[gr.Markdown(label="Response:")],
    flagging_mode="never"
)
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
